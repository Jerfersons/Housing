# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('house_prices.csv')

# %%
df.head()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Description', 'Amount(in rupees)',
#        'Price (in rupees)', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Society',
#        'Bathroom', 'Balcony', 'Car Parking', 'Ownership', 'Super Area',
#        'Dimensions', 'Plot Area'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  object
#  6   Carpet Area        106858 non-null  object
#  7   Status             186916 non-null  object
#  8   Floor              180454 non-null  object
#  9   Transaction        187448 non-null  object
#  10  Furnishing         184634 non-null  object
#  11  facing             117298 non-null  object
#  12  overlooking        106095 non-null  object
#  13  Society            77853 non-null   object
#  14  Bathroom           186703 non-null  object
# ...

# %%
df.size
# Out:
# 3938151

# %%
df.drop(['Plot Area','Dimensions'], axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  object
#  6   Carpet Area        106858 non-null  object
#  7   Status             186916 non-null  object
#  8   Floor              180454 non-null  object
#  9   Transaction        187448 non-null  object
#  10  Furnishing         184634 non-null  object
#  11  facing             117298 non-null  object
#  12  overlooking        106095 non-null  object
#  13  Society            77853 non-null   object
#  14  Bathroom           186703 non-null  object
# ...

# %% [markdown]
# 1. Data seems to  be from india because all curriencies are in rupees
# 2. Curiosity for location of these houses has picked my interest

# %%
locations=df.value_counts('location')

# %%
print(locations.values)
# Out:
# [27599 24030 22380 20070 12750 12300 10500  8490  4710  3840  2388  2370
#   2225  1933  1860  1800  1710  1530  1440  1281  1200  1080  1050  1050
#    990   931   896   780   780   750   750   720   718   714   630   600
#    570   510   510   456   450   450   450   390   390   360   345   270
#    270   210   210   180   180   180   180   150   150   150   150   144
#    121   120   120   120    90    90    90    60    60    60    60    60
#     60    60    30    30    30    30    30    30    30]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(28,12))
gtf
ax.bar(locations.index, locations.values)

ax.set_ylabel('number of houses')
ax.set_xlabel('locations')
ax.set_title('number of houses in each location')
ax.legend(title='number of houses in each location')
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
location_new_delhi=df[df['location']=='new-delhi']

# %%
result=df.groupby('location')['Price (in rupees)'].mean()

# %%
fig, ax = plt.subplots(figsize=(28,12))

ax.bar(result.index, result.values)

ax.set_ylabel('maximum price of houses')
ax.set_xlabel('locations')
ax.set_title('maximum price of houses')
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees

plt.show()

# %%
df['sqft area']=df['Carpet Area'].str.replace('\D', '', regex=True)
df['sqft area']= df['sqft area'].fillna(0)
df['sqft area']=df['sqft area'].astype('int')
sqft_area=df.groupby('location')['sqft area'].mean()

# %%
fig, ax = plt.subplots(figsize=(28,12))
ax.bar(sqft_area.index, sqft_area.values)

ax.set_ylabel('sqft area')
ax.set_xlabel('locations')
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
ax.set_title('Mean sqft area by location')

plt.show()

# %%
df['Status'].value_counts()
# Out:
# Status
# Ready to Move    186916
# Name: count, dtype: int64

# %%
results=df.groupby('location')['Status'].count()
        
results
# Out:
# location
# agra               449
# ahmadnagar          30
# ahmedabad        12740
# allahabad          180
# aurangabad         449
#                  ...
# varanasi           270
# vijayawada         568
# visakhapatnam     1800
# vrindavan           60
# zirakpur          1528
# Name: Status, Length: 81, dtype: int64

# %% [markdown]
# Colum to fill empty values with Zero

# %%
df['Status_numeric']= df['Status'].fillna(0)
df['Status_numeric']= df[df['Status_numeric']=='Ready to Move']=1

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  object
#  6   Carpet Area        106858 non-null  object
#  7   Status             186916 non-null  object
#  8   Floor              180454 non-null  object
#  9   Transaction        187448 non-null  object
#  10  Furnishing         184634 non-null  object
#  11  facing             117298 non-null  object
#  12  overlooking        106095 non-null  object
#  13  Society            77853 non-null   object
#  14  Bathroom           186703 non-null  object
# ...

# %% [markdown]
# Plotting the graph of location by status
#     - The status column contains apartments that are ready to move and not ready to move

# %%
location_status=df.groupby('location')['Status_numeric'].sum()

# %%
fig, ax = plt.subplots(figsize=(28,12))
ax.bar(location_status.index, location_status.values)
ax.set_ylabel('number of houses that are ready to move')
ax.set_xlabel('locations')
ax.set_title('Distribution of houses that are ready to be moved into.')


plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees


plt.show()

# %% [markdown]
# Based  on the data, New Dehli has the highest amount of houses to be moved into due to having the highest total number of houses in the data set.

# %%
df['Ownership'].value_counts()
# Out:
# Ownership
# Freehold                112229
# Leasehold                 5285
# Co-operative Society      3431
# Power Of Attorney         1069
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18,12))

sns.lineplot(x="location",y='Price (in rupees)',
             hue="Ownership",
             data=df,ax=ax)
ax.set_ylabel('total house prices')
ax.set_xlabel('locations')
ax.set_title('Distribution of houses against its ownership status')


plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees


plt.show()
